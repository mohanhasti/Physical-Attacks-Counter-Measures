# %%
import pandas as pd
import numpy as np
from time import time
import matplotlib.pyplot as plt
import math
# import multiprocessing as mp
from  multiprocessing import Pool

# %%
traces = np.load('data/traces_attack_hw3/traces_attack_int16.npy')

# %%
# traces = np.load('C:/Users/coe_user/Desktop/PhyAttcks/hw3/data/traces_attack_hw3/traces_attack_int16.npy')
# plain_text= np.load('C:/Users/coe_user/Desktop/PhyAttcks/hw3/data/traces_attack_hw3/textin_attack.npy')
# text_out = np.load('C:/Users/coe_user/Desktop/PhyAttcks/hw3/data/traces_attack_hw3/textout_attack.npy')

# %%
means = np.mean(traces, axis=0)
# print(means.shape)
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(means, 'black')
ax.set_xlabel('Traces')
ax.set_ylabel('Value')
plt.show()
